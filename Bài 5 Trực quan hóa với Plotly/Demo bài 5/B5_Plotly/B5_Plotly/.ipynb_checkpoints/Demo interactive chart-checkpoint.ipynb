# %%
import numpy as np
import pandas as pd
from datetime import datetime
import plotly.express as px

# %%
# Tải tập dữ liệu Gapminder
gapminder = px.data.gapminder()

# Hiển thị 5 dòng đầu của DataFrame để kiểm tra dữ liệu
gapminder.head()

# %%
# Chọn dữ liệu năm gần nhất 
max_year= gapminder['year'].max()

df_latest = gapminder[gapminder['year'] == max_year]
df_latest

# %%
# Tính tổng dân số cho mỗi châu lục năm sau cùng trong tập dữ liệu
df_continent=df_latest.groupby(['continent','year']).sum().reset_index()
df_continent.head()

# %% [markdown]
# ### Plotly express vs Plotly graph object

# %%
import plotly.express as px

# Vẽ biểu đồ bar
fig = px.bar(data_frame=df_continent,
             x='continent',
             y='pop',
             title='Dân số các châu lục - ' + str(max_year),
             labels={'pop':'Population', 'continent':'Continent'})

# Hiển thị biểu đồ
fig.show()

# %%
import plotly.graph_objects as go

# %%
# Tạo trace
trace = go.Bar(
    x=df_continent['continent'],
    y=df_continent['pop'],
    marker=dict(color='royalblue')
)
# Tạo layout
layout = go.Layout(
    title='Dân số các châu lục - ' + str(max_year) ,
    xaxis=dict(title='Continent'),
    yaxis=dict(title='Population')
)
# Tạo figure và thêm trace
fig = go.Figure(data=[trace], layout=layout)

# Hiển thị biểu đồ
fig.show()

# %%
from plotly.subplots import make_subplots

# %%
fig = make_subplots(rows=1, cols=2)

fig.add_trace(
    go.Scatter(x=[1, 2, 3], y=[4, 5, 6]),
    row=1, col=1
)

fig.add_trace(
    go.Scatter(x=[20, 30, 40], y=[50, 60, 70]),
    row=1, col=2
)

fig.update_layout(height=600, width=800, title_text="Side By Side Subplots")
fig.show()

# %%
fig = px.histogram(data_frame=gapminder,x='lifeExp',facet_col='continent',facet_col_wrap=3)
fig.show()

# %% [markdown]
# ### Trực quan hóa dữ liệu tương tác với Plotly

# %% [markdown]
# ### Scatter

# %%
# Tạo biểu đồ scatter
fig = px.scatter(data_frame=df_latest, 
                 x="gdpPercap", 
                 y="lifeExp", 
                 color='continent',
                 hover_name='country',
                 size='pop',title='GPD vs LifeExp',
                 size_max=50
                 )
# Hiển thị biểu đồ
fig.show()

# %% [markdown]
# ##### Hãy sử dụng tính năng tương tác của biểu đồ trên để trả lời cho các câu hỏi sau:
# 1. Quốc gia nào có tuổi thọ cao nhất ?
# 2. Quốc gia nào có tuổi thọ cao nhất ở châu Á, châu Mỹ?
# 3. Quốc gia nào có dân số đông nhất ở châu Mỹ?
# 4. Quốc gia nào có tuổi thọ thấp nhất ở châu Âu?
# 5. Quốc gia nào có tuổi thọ và gdpPercap thấp nhất thế giới?
# 6. Các quốc gia có tuổi thọ trung bình trên 80. Các quốc gia này tập trung chủ yếu ở châu lục nào?
# 7. Quốc gia nào có GDP per capita thấp nhất.
# 8. Châu lục nào có sự chênh lệch tuổi thọ lớn nhất giữa các quốc gia trong châu lục đó?

# %% [markdown]
# ### Box plot

# %%
fig_box = px.box(df_latest,
                 y='lifeExp',
                 title='Phân bố tuổi thọ trung bình của các châu lục')
fig_box.show()

# %%
# Vẽ biểu đồ box plot cho tuổi thọ trung bình của các châu lục
fig_box = px.box(df_latest,
                 x='continent', y='lifeExp',
                 hover_name='country',
                 title='Phân bố tuổi thọ trung bình của các châu lục')
fig_box.show()

# %% [markdown]
# ##### Hãy sử dụng tính năng tương tác của biểu đồ trên để trả lời cho các câu hỏi sau:
# <ol>
# <li> Châu lục nào có trung vị tuổi thọ cao nhất?  </li>
# <li> Châu lục nào có trung vị tuổi thọ thấp nhất</li>
# <li>  Châu lục nào phạm vi biến động tuổi thọ (IQR) nhiều nhất</li>
# <li> Châu lục nào có phạm vi biến động tuổi thọ (IQR) ít nhất?</li>
# <li>    Có bất kỳ châu lục nào có giá trị ngoại lệ (outliers)? Những quốc gia này có gì đặc biệt ? </li>
# <li>    Châu lục nào có phạm vi tuổi thọ rộng, tính nhất từ giá trị nhỏ nhất  đến giá trị lớn nhất </li>
# <li> Hãy nhận xét phân bố tuổi thọ giữa châu Âu và  châu Á. </li>
# <li>     Các giá trị tuổi thọ tại các châu lục khác biệt nhau như thế nào so với tuổi thọtrung bình toàn cầu? </li>
# </ol?

# %%
#Mở rộng - Tham khảo
# Vẽ biểu đồ box plot cho tuổi thọ trung bình của các châu lục
fig_box = px.box(df_latest,
                 x='continent', y='lifeExp',
                 title='Phân bố tuổi thọ trung bình của các châu lục')

global_life_expectancy_avg = df_latest['lifeExp'].mean()

# Thêm một đường ngang cho trung bình tuổi thọ toàn cầu
fig_box.add_trace(
    go.Scatter(
        x=df_latest['continent'].unique(),  # Trục x, bao gồm tất cả các châu lục
        y=[global_life_expectancy_avg]*5,  # Trục y là giá trị trung bình tuổi thọ, lặp lại cho mỗi châu lục
        mode='lines',  # Đặt chế độ vẽ là 'lines'
        name='Trung bình tuổi thọ toàn cầu',  # Tên của đường trung bình
        line=dict(color='red', dash='dash')  # Định dạng đường là nét đứt màu đỏ
    )
)
fig_box.show()

# %% [markdown]
# ### Histogram

# %%
# Vẽ histogram cho tuổi thọ trung bình của các nước
fig_hist = px.histogram(df_latest,
                        x='lifeExp',
                        color='continent',
                        title='Phân bố tuổi thọ trung bình của các nước',
                        color_discrete_sequence=px.colors.sequential.Bluyl,
                        nbins=25)
fig_hist.show()

# %% [markdown]
# ##### Hãy sử dụng tính năng tương tác của biểu đồ trên để trả lời cho các câu hỏi sau:
# <ol>
# <li> Bạn có nhận xét gì về phân bố tuổi thọ trung bình giữa các châu lục ?</li>
# <li> Mật độ dữ liệu cao nhất, tức là tuổi thọ trung bình tập trung nhiều nhất trong khoảng giá trị nào ?</li>
# <li> Theo bạn, giá trị outliers của tuổi thọ trung bình là những giá trị nào, ở châu lục nào? </li>
# <li> Quan sát số lượng quốc gia cụ thể trong mỗi khoảng giá trị (bin) tuổi thọ trung bình và cho biết khoảng bin nào có nhiều quốc gia nhất?  </li>
# <li> Quan sát số lượng quốc gia cụ thể trong mỗi khoảng giá trị (bin) tuổi thọ trung bình và cho biết khoảng bin nào có ít quốc gia nhất?  </li>
# </ol>

# %% [markdown]
# ### Treemap

# %%
df_latest.groupby(['continent','country'],as_index=False)['pop'].sum()

# %%
fig = px.treemap(data_frame=df_latest, path=['continent','country'], values='pop',
                  color='lifeExp', hover_data=['gdpPercap','iso_alpha'],
                 hover_name='country',
                  #color_continuous_scale='RdBu',
                  title='Treemap của Dân số và Tuổi thọ theo Quốc gia và Châu lục')

fig.update_layout(
    width=1000,  # Chiều rộng của biểu đồ bằng pixel
    height=500,   # Chiều cao của biểu đồ bằng pixel
    margin = dict(t=40, l=0, r=0, b=0))
fig.show()

# %% [markdown]
# ##### Hãy sử dụng tính năng tương tác của biểu đồ trên để trả lời cho các câu hỏi sau:
# <ol>
# <li> Châu lục nào có tổng dân số lớn nhất?  </li>
# <li> Quốc gia nào có tuổi thọ trung bình cao nhất ?</li>
# <li> Quốc gia nào có tuổi thọ trung bình thấp nhất mà bạn có thể tìm thấy? </li>
# <li> Quan sát biểu đồ bạn có nhận xét gì về Châu Á?  </li>
# <li> Quan sát biểu đồ bạn có nhận xét gì về Châu Phi?  </li>
# </ol>
# g của họ?

# %% [markdown]
# ### Pie chart

# %%
# Vẽ biểu đồ pie chart
fig = px.pie(
    df_continent,
    values='pop',
    names='continent',
    title='Tỷ lệ dân số các châu lục',
    color_discrete_sequence=px.colors.qualitative.D3
)
fig.update_traces(
                  textposition="outside")
fig.update_layout(
    width=600,  # Chiều rộng của biểu đồ bằng pixel
    height=350,   # Chiều cao của biểu đồ bằng pixel
    margin = dict(t=40, l=50, r=25, b=25),
    showlegend=True)
# Hiển thị biểu đồ
fig.show()

# %% [markdown]
# ### Bar chart

# %%
df_continent

# %%
df_latest.continent.value_counts()

# %%
# Vẽ biểu đồ bar hiển thị dân số của mỗi châu lục
fig_bar = px.bar(df_continent,
                 x='continent', y='pop',
                 color='lifeExp',
                 title='Dân số của các châu lục')
fig_bar.show()

# %%
df_latest.head()

# %%
# Vẽ biểu đồ stack bar hiển thị dân số của mỗi quốc gia trong châu lục
fig_bar = px.bar(df_latest,x='continent', y='pop',color='lifeExp',title='Dân số của mỗi châu lục',hover_data=['country','iso_alpha'],
                hover_name='country')
fig_bar.show()

# %% [markdown]
# ***Hãy quan sát 2 biểu đồ Bar vừa vẽ và cho biết nhận xét***
