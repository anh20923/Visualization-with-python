# %% [markdown]
# ## Plotly_Exercise1_Athletes
# Tập dữ liệu **athletes.csv** chứa thông tin về các vận động viên tham gia thế vận hội Olimpic RIO 2016, bao gồm tên, quốc gia, giới tính, ngày sinh, năm sinh, tuổi, chiều cao, cân nặng, môn thể thao và số lượng huy chương đạt được.
#
# ## Hãy thực hiện các yêu cầu sau:
# ### Câu 1:
# Đọc dữ liệu từ tệp athletes.csv
# Hiển thị 5 dòng đầu, 5 dòng cuối Hiển thị thông tin info và describe
#
# ## Hãy vẽ các biểu đồ sau đây và trả lời các câu hỏi tương tác
# ### Câu 2:
# Đọc dữ liệu từ country.csv, lưu vào biến countries
# Merge dữ liệu athletes với countries, ưu tiên dataframe athletes
# ### Câu 3:
# Vẽ biểu đồ boxplot thể hiện phân bố tuổi của các VĐV theo môn thi đấu
# ### Câu 4:
# Vẽ biểu đồ scatter thể hiện Tương quan chiều cao, cân nặng của các VĐV bóng chuyền, có hiển thị trendline
# ### Câu 5:
# Vẽ biểu đồ histogram thể hiện phân phối chiều cao của các VĐV bóng chuyền
# ### Câu 6:
# Vẽ biểu đồ histogram với x='age', y="total" để thể hiện Tổng số huy chương theo độ tuổi
# ### Câu 7:
# Vẽ biểu đồ histogram với y = 'Country', x = 'total' để hiển thị tổng số huy chương của mỗi quốc gia
# ### Câu 8:
# Thống kê số VĐV và tổng số huy chương của các quốc gia tham gia OLYMPIC
# ### Câu 9:
# Vẽ scatter_geo với phép chiếu Natural earth thể hiện số lượng VĐV của các quốc gia
# ### Câu 10:
# Vẽ Choropleth map thể hiện số huy chương của các quốc gia

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
# Câu 1: Đọc dữ liệu

# Xem 5 dòng đầu tiên

# %%
# Xem 5 dòng cuối

# %%
# Xem thông tin info

# %%
# Xem thông tin describe của các cột số

# %%
# Xem thông tin describe của các cột object

# %%
# Câu 2: Đọc dữ liệu từ country.csv, lưu vào biến countries

# %%
# Merge dữ liệu athletes với countries, ưu tiên dataframe athletes

# %%
# Câu 3: Vẽ biểu đồ boxplot thể hiện phân bố tuổi của các VĐV theo môn thi đấu

# %% [markdown]
# ##### Hãy sử dụng tính năng tương tác của biểu đồ trên để trả lời cho các câu hỏi sau:
# 1. Vận động viên thi đấu ở môn thể thao nào có độ tuổi cao nhất?
# 2. Vận động viên thi đấu ở môn thể thao nào có độ tuổi thấp nhất?
# 3. VĐV trẻ nhất thi đấu ở môn thể thao nào?
# 4. Cho biết thông tin của VĐV lớn tuổi nhất tham gia thi đua thuyền (rowing): Tên, Quốc gia, châu lục, số huy chương đạt được.
# 5. Cho biết độ tuổi của các VĐV bóng đá (min, Q1, median, Q3, max)

# %%
# Câu 4: Vẽ biểu đồ scatter thể hiện Tương quan chiều cao, cân nặng của các VĐV bóng chuyền, có hiển thị trendline

# %% [markdown]
# ##### Hãy sử dụng tính năng tương tác của biểu đồ trên để trả lời cho các câu hỏi sau:
# 1. Chiều cao, cân nặng của các VĐV bóng chuyền có tương quan với nhau như thế nào?
# 2. Cho biết tên và số huy chương của VĐV nữ thấp nhất, cao nhất?
# 3. Cho biết tên và số huy chương của VĐV nam có cân nặng lớn nhất?
# 4. Cho biết phương trình của đường hồi quy tuyến tính chiều cao của các VĐV nam theo cân nặng.

# %%
# Câu 5: Vẽ biểu đồ histogram thể hiện phân phối chiều cao của các VĐV bóng chuyền

# %%
# Câu 6: Vẽ biểu đồ histogram với x='age', y="total" để thể hiện Tổng số huy chương theo độ tuổi

# %% [markdown]
# ##### Hãy sử dụng tính năng tương tác của biểu đồ trên để trả lời cho các câu hỏi sau:
# 1. VĐV trong độ tuổi nào đạt được nhiều huy chương nhất?
# 2. VĐV nhỏ tuổi nhất đạt được huy chương là bao nhiêu tuổi?
# 3. VĐV lớn tuổi nhất đạt được huy chương là bao nhiêu tuổi?
# 4. Tổng số huy chương của các VĐV 27 tuổi đạt được là bao nhiêu?

# %%
# Câu 7: Vẽ biểu đồ histogram với y = 'Country', x = 'total' để hiển thị tổng số huy chương của mỗi quốc gia

# %% [markdown]
# ##### Hãy sử dụng tính năng tương tác của biểu đồ trên để trả lời cho các câu hỏi sau:
# 1. Quốc gia nào đạt nhiều huy chương nhất? Số huy chương là bao nhiêu?
# 2. Cho biết quốc gia đứng thứ 2 về tổng số huy chương.
# 3. Cho biết Norway đạt được bao nhiêu huy chương?

# %%
# Câu 8: Thống kê số VĐV và tổng số huy chương của các quốc gia tham gia OLYMPIC

# %%
# Câu 9: Vẽ scatter_geo với phép chiếu Natural earth thể hiện số lượng VĐV của các quốc gia

# Hiển thị biểu đồ

# %% [markdown]
# ##### Hãy sử dụng tính năng tương tác của biểu đồ trên để trả lời cho các câu hỏi sau:
# 1. Quốc gia nào nhiều VĐV nhất?
# 2. Việt Nam có bao nhiêu VĐV tham gia thi đấu?
# 3. Quốc gia nào nhiều VĐV tham gia nhất ở châu Á?
# 4. Quốc gia nào nhiều VĐV tham gia nhất ở châu Âu?
# 5. Châu Đại Dương có bao nhiêu quốc gia tham gia?

# %%
# Câu 10: Vẽ Choropleth map thể hiện số huy chương của các quốc gia

# Show the map

# %% [markdown]
# ##### Hãy sử dụng tính năng tương tác của biểu đồ trên để trả lời cho các câu hỏi sau:
# 1. Cho biết 3 quốc gia đạt được nhiều huy chương nhất và số huy chương đạt được?
# 2. Châu lục nào không có quốc gia đạt > 50 huy chương?
# 3. Cho biết tổng số huy chương của Canada, Trung Quốc, Việt Nam, Nhật Bản, Australia?
