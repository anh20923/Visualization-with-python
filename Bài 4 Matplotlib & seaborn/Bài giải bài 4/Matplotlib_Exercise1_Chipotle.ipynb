# %% [markdown]
# ## Chapter 6 - Exercise 1: Trực quan hóa dữ liệu Chipotle

# %% [markdown]
# #### Cho dữ liệu https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv

# %% [markdown]
# Nhà hàng Chipotle là một chuỗi nhà hàng thức ăn nhanh, chuyên cung cấp các món ăn với nguồn gốc từ ẩm thực Mexico. Tại đây khách hàng có thể tùy chọn các thành phần để tạo nên bữa ăn của họ. Nhà hàng cần phân tích dữ liệu bán được trong ngày diễn ra khuyến mãi để có thể điều chỉnh thực đơn và thực hiện các chương trình khuyến mãi phù hợp. Dữ liệu gồm những cột sau:
# - order_id: mã đơn hàng
# - quantity: số lượng
# - item_name: tên món ăn
# - choice_description: mô tả món ăn (những yêu cầu thêm)
# - item_price: giá bán
#
# Dữ liệu được cung cấp trong file chipotle.tsv, hãy thực hiện các yêu cầu sau:

# %% [markdown]
# # Yêu cầu

# %% [markdown]
# ### Câu 1:
# - Đọc dữ liệu và gán vào biến chipo
# - Hiển thị 10 dòng đầu của dữ liệu
# - Xem thông tin info()
#
# ### Câu 2:
# - a) Đổi kiểu dữ liệu của cột item_price sang kiểu số thực
# - b) Tạo cột revenue, với revenue = quantity * item_price
#
# ### Câu 3:
# - a) Tạo dataframe df gồm 2 cột: tên món ăn và đếm số lần gọi
# - b) Sắp xếp df theo tần suất tăng dần, và lấy 5 item cuối cùng
# - c) Vẽ biểu đồ bar chart cho biết 5 món được gọi nhiều lần nhất, có title, xlabel, ylabel và xticks
#
# ### Câu 4:
# Nhóm các đơn hàng theo order_id, và tính tổng số lượng gọi và tổng giá trị của mỗi đơn hàng, in kết quả
#
# ### Câu 5:
# - a) Từ câu 4, hãy vẽ scatterplot với x là quantity, và y là revenue, có title, xlabel, ylabel. Bạn có nhận xét gì qua biểu đồ này
# - b) Từ biểu đồ ở câu 5a, hãy đặt plt.yscale('log'), xem kết quả và nhận xét.
#
# ### Câu 6:
# - a) Vẽ barh chart thể hiện 5 món có tổng thành tiền lớn nhất
# - b) Vẽ biểu đồ barplot cho biết 5 món được gọi nhiều nhất và trung bình item_price
# - c) Vẽ biểu đồ barplot cho biết 5 món được gọi nhiều nhất và trung bình revenue
#
# ### Câu 7:
# - a) Vẽ histogram của item_price
# - b) Vẽ histogram của item_price với bins = 3
# - c) Hãy in ra khoảng giá trị item_price và số lần gọi món tương ứng với biểu đồ ở câu 7b

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Câu 1: Đọc dữ liệu và gán vào biến chipo 
chipo = pd.read_csv('chipotle.tsv', sep = '\t')
# Hiển thị 10 dòng đầu của dữ liệu
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
#   <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>order_id</th>
#       <th>quantity</th>
#       <th>item_name</th>
#       <th>choice_description</th>
#       <th>item_price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Chips and Fresh Tomato Salsa</td>
#       <td>NaN</td>
#       <td>\$2.39</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Izze</td>
#       <td>[Clementine]</td>
#       <td>\$3.39</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Nantucket Nectar</td>
#       <td>[Apple]</td>
#       <td>\$3.39</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Chips and Tomatillo-Green Chili Salsa</td>
#       <td>NaN</td>
#       <td>\$2.39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>2</td>
#       <td>Chicken Bowl</td>
#       <td>[Tomatillo-Red Chili Salsa (Hot), [Black Beans...</td>
#       <td>\$16.98</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>3</td>
#       <td>1</td>
#       <td>Chicken Bowl</td>
#       <td>[Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...</td>
#       <td>\$10.98</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>3</td>
#       <td>1</td>
#       <td>Side of Chips</td>
#       <td>NaN</td>
#       <td>\$1.69</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>4</td>
#       <td>1</td>
#       <td>Steak Burrito</td>
#       <td>[Tomatillo Red Chili Salsa, [Fajita Vegetables...</td>
#       <td>\$11.75</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>4</td>
#       <td>1</td>
#       <td>Steak Soft Tacos</td>
#       <td>[Tomatillo Green Chili Salsa, [Pinto Beans, Ch...</td>
#       <td>\$9.25</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>5</td>
#       <td>1</td>
#       <td>Steak Burrito</td>
#       <td>[Fresh Tomato Salsa, [Rice, Black Beans, Pinto...</td>
#       <td>\$9.25</td>
#     </tr>
#   </tbody>
# </table>
# </div>
# </details>

# %%
# Xem thông tin info()
chipo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
# Câu 2: 
# a) Đổi kiểu dữ liệu của cột item_price sang kiểu số thực 
chipo.item_price = chipo.item_price.str.replace('$','',regex=False).astype(float)

# %%
# b) Tạo cột revenue, với revenue = quantity * item_price
chipo['revenue'] = chipo.quantity * chipo.item_price
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  revenue
# 0                                                NaN        2.39     2.39
# 1                                       [Clementine]        3.39     3.39
# 2                                            [Apple]        3.39     3.39
# 3                                                NaN        2.39     2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98    33.96

# %%
# Câu 3a: tạo dataframe df gồm 2 cột: tên món ăn và đếm số lần gọi
df = chipo.groupby('item_name',as_index=False)['order_id'].count().rename(columns={'order_id':'cnt'})
df.head()
# Out:
#                item_name  cnt
# 0      6 Pack Soft Drink   54
# 1          Barbacoa Bowl   66
# 2       Barbacoa Burrito   91
# 3  Barbacoa Crispy Tacos   11
# 4    Barbacoa Salad Bowl   10

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
#   <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>item_name</th>
#       <th>cnt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6 Pack Soft Drink</td>
#       <td>54</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Barbacoa Bowl</td>
#       <td>66</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Barbacoa Burrito</td>
#       <td>91</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Barbacoa Crispy Tacos</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Barbacoa Salad Bowl</td>
#       <td>10</td>
#     </tr>
#   </tbody>
# </table>
# </details>

# %%
# b) Sắp xếp df theo tần suất tăng dần, và lấy 5 item cuối cùng
top5 = df.sort_values('cnt').tail()
top5
# Out:
#               item_name  cnt
# 10    Canned Soft Drink  301
# 39        Steak Burrito  368
# 25  Chips and Guacamole  479
# 18      Chicken Burrito  553
# 17         Chicken Bowl  726

# %%
# c) Vẽ biểu đồ bar chart cho biết 5 món được gọi nhiều lần nhất 
# (có title, xlabel, ylabel và xticks)
plt.bar(top5.item_name,height=top5.cnt)
plt.title('5 món được gọi nhiều lần nhất ')
plt.xlabel('Món ăn')
plt.ylabel('Số lần gọi')
plt.xticks(rotation=75)
plt.show()

# %%
# Câu 4) Nhóm các đơn hàng theo order_id, và tính tổng số lượng gọi 
# và tổng giá trị của mỗi đơn hàng, 
# in kết quả
df_cau4 = chipo.groupby('order_id')[['quantity','revenue']].sum()
df_cau4.head()
# Out:
#           quantity  revenue
# order_id
# 1                4    11.56
# 2                2    33.96
# 3                2    12.67
# 4                2    21.00
# 5                2    13.70

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>quantity</th>
#       <th>revenue</th>
#     </tr>
#     <tr>
#       <th>order_id</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>11.56</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>33.96</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>12.67</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>21.00</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>13.70</td>
#     </tr>
#   </tbody>
# </table>
# </details>

# %%
# Câu 5: Từ câu 4, hãy vẽ scatterplot với x là quantity, và y là revenue, có title, xlabel, ylabel
# Bạn có nhận xét gì qua biểu đồ này 
plt.scatter(df_cau4.quantity,df_cau4.revenue)
# Thiết lập title và labels

# %%
# b) Từ biểu đồ ở câu 5a, hãy đặt plt.yscale('log'), xem kết quả và nhận xét. 
plt.scatter(df_cau4.quantity,df_cau4.revenue)
plt.yscale('log')
# Thiết lập title và labels

# %%
# Câu 6: vẽ barh chart thể hiện 5 món có tổng thành tiền lớn nhất
tmp = chipo.groupby('item_name',as_index=False)['revenue'].sum().sort_values('revenue').tail()
plt.barh(tmp.item_name,width=tmp.revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
# b) Vẽ biểu đồ barplot cho biết 5 món được gọi nhiều nhất và trung bình item_price
ind = chipo.item_name.value_counts().head().index
df = chipo[chipo.item_name.isin(ind)].groupby('item_name',as_index=False)[['item_price','revenue']].mean()
df
# Out:
#              item_name  item_price    revenue
# 0    Canned Soft Drink    1.457641   2.005814
# 1         Chicken Bowl   10.113953  11.080758
# 2      Chicken Burrito   10.082857  11.549837
# 3  Chips and Guacamole    4.595073   5.168309
# 4        Steak Burrito   10.465842  11.511223

# %%
plt.barh(df.item_name,width=df.item_price)
# Out:
# <BarContainer object of 5 artists>

# %%
# c) Vẽ biểu đồ barplot cho biết 5 món được gọi nhiều nhất và trung bình revenue
plt.barh(df.item_name,width=df.revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
# Câu 7a: Vẽ histogram của item_price
plt.hist(chipo.item_price);

# %%
# b) Vẽ histogram của item_price với bins = 3
plt.hist(chipo.item_price,bins=3)
# Out:
# (array([4495.,  121.,    6.]),
#  array([ 1.09      , 15.47666667, 29.86333333, 44.25      ]),
#  <BarContainer object of 3 artists>)

# %%
# c) Hãy in ra khoảng giá trị item_price và số lần gọi món tương ứng với biểu đồ ở câu 7b
counts,bins,bars = plt.hist(chipo.item_price,bins=3)
# Nhận thông tin về bins
for i in range(len(bins)-1):
    print(f"Gia trị trong khoảng {bins[i]}-{bins[i+1]} : {counts[i]} lần xh")
# In ra giá trị và số lượng của mỗi bin
# Out:
# Gia trị trong khoảng 1.09-15.476666666666665 : 4495.0 lần xh
# Gia trị trong khoảng 15.476666666666665-29.86333333333333 : 121.0 lần xh
# Gia trị trong khoảng 29.86333333333333-44.25 : 6.0 lần xh
