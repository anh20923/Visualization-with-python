# %% [markdown]
# ## Seaborn - Exercise 2: Titanic

# %% [markdown]
# Vào ngày 15 tháng 4 năm 1912, trong chuyến hải trình đầu tiên của mình, tàu Titanic đã chìm sau khi va chạm với một tảng băng trôi, đã có 1502 nạn nhân mãi mãi ra đi trong tổng số 2224 hành khách và thủy thủ đoàn.
#
# Tập dữ liệu **train.csv** chứa thông tin về hành khách trên tàu Titanic với ý nghĩa các cột như sau:
# 1.	PassengerId: ID của mỗi hành khách.
# 2.	Survived: cho biết hành khách còn sống sót (1) hay không (0).
# 3.	Pclass: Hạng vé của hành khách (1 = Hạng nhất, 2 = Hạng hai, 3 = Hạng ba).
# 4.	Name: Tên đầy đủ của hành khách.
# 5.	Sex: Giới tính của hành khách.
# 6.	Age: Tuổi của hành khách.
# 7.	SibSp: Số lượng anh chị em hoặc vợ/chồng đi cùng trên tàu.
# 8.	Parch: Số lượng cha mẹ hoặc con cái đi cùng trên tàu.
# 9.	Ticket: Mã số vé.
# 10.	Fare: Giá vé.
# 11.	Cabin: Số hiệu phòng ngủ trên tàu.
# 12.	Embarked: Cảng mà hành khách lên tàu (C = Cherbourg; Q = Queenstown; S = Southampton).

# %% [markdown]
# #### Dựa trên tập tin _train.csv_ , hãy thực hiện các yêu cầu sau:
# ### Câu 1:
# a) Đọc dữ liệu từ tập tin train.csv và lưu vào biến titanic.
# Hiển thị 5 dòng dữ liệu đầu của titanic
# b) Xem thông tin info, describe
# ### Câu 2:
# a) Vẽ biểu đồ Countplot Thống kê số lượng hành khách theo Survived
# b) Vẽ biểu đồ Countplot Thống kê số lượng hành khách theo Survived và Sex
# c) Vẽ biểu đồ Countplot Thống kê số lượng hành khách theo Survived và Pclass
# d) Vẽ biểu đồ Countplot Thống kê số lượng hành khách theo Embarked và Survived
# e) Vẽ biểu đồ Countplot Thống kê số lượng hành khách theo Pclass và Sex
# ### Câu 3
# a) Vẽ biểu đồ Barplot thể hiện tuổi trung bình của hành khách theo giới tính
# b) Vẽ biểu đồ Barplot thể hiện tuổi trung bình theo hạng vé
# ### Câu 4:
# a) Vẽ biểu đồ histogram thể hiện phân phối tuổi của hành khách
# b) Vẽ đồ thị hàm mật độ xác suất tuổi của hành khách theo Survived
# c) Vẽ biểu đồ boxplot thể hiện phân phối tuổi của hành khách theo Survived
#
# ### Câu 5:
# a) Vẽ biểu đồ histogram của cột giá vé (Fare)
# b) Vẽ biểu đồ histogram của cột vé (Fare) theo bin với giá vé cách đều 10$
# c) Vẽ biểu đồ violin thể hiện Phân bố của giá vé theo Pclass và Survived

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Câu 1: 
# a) Đọc dữ liệu từ tập tin train.csv và lưu vào biến titanic.  
titanic = pd.read_csv('train.csv')
# Hiển thị 5 dòng dữ liệu đầu của titanic
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# b) Xem thông tin info, describe

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.describe(include='O')
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %%
# Câu 2a) Thống kê số lượng hành khách theo Survived

# %%
sns.countplot(data=titanic,x='Survived',hue='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# b) Thống kê số lượng hành khách theo Survived và Sex

# %%
sns.countplot(data=titanic,x='Survived',hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# c) Thống kê số lượng hành khách theo Survived và Pclass (hạng vé)
sns.countplot(data=titanic,hue='Survived',x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# d) Thống kê số lượng hành khách theo Survived và Embarked (nơi lên tàu)
sns.countplot(data=titanic,hue='Survived',x='Embarked')
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
# e) Thống kê số lượng hành khách theo Pclass và Sex 
sns.countplot(data=titanic,hue='Sex',x='Pclass')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# Câu 3a: Vẽ biểu đồ Barplot thể hiện tuổi trung bình của hành khách theo giới tính
sns.barplot(data=titanic,x='Sex',y='Age',errorbar=None,hue='Sex');

# %%
# b: vẽ biểu đồ Barplot thể hiện tuổi trung bình theo hạng vé
sns.barplot(data=titanic,x='Pclass',y='Age',errorbar=None,hue='Pclass',palette='Set1');

# %%
# Câu 4a: Vẽ biểu đồ histogram thể hiện phân phối tuổi của hành khách
sns.displot(data=titanic,x='Age')

# Thiết lập các thông tin xlabel, ylabel, title
plt.xlabel('Tuổi')
plt.ylabel('Số lần xh')
plt.show()

# %%
# b) Vẽ đồ thị hàm mật độ xác suất tuổi của hành khách theo Survived
sns.displot(data=titanic,x='Age',kind='kde',hue='Survived')

# %%
# c) Vẽ biểu đồ boxplot thể hiện phân phối tuổi của hành khách theo Survived
sns.boxplot(data=titanic,x='Survived',y='Age',hue='Survived');

# %%
# Câu 5a: Vẽ biểu đồ histogram của cột giá vé (Fare)
sns.displot(data=titanic,x='Fare')
# Vẽ histogram với dữ liệu là titanic


# Thiết lập các thông tin xlabel, ylabel, title

# %%
# b: Vẽ biểu đồ histogram của cột vé (Fare) theo bin với giá vé cách đều 10$
'''
Gợi ý:
- Tạo binsVal = np.arange(0,600,10)
- Vẽ histogram với bins = binsVal
'''
# Tạo binsVal = np.arange(0,600,10)

binsVal = np.arange(0,600,10)
# Vẽ histogram với dữ liệu là titanic với bins
sns.histplot(data=titanic,x='Fare',bins=binsVal)

# Thiết lập các thông tin xlabel, ylabel, title
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
# c) Vẽ biểu đồ violin thể hiện Phân bố của giá vé theo Pclass và Survived
sns.violinplot(data=titanic,x='Pclass',y='Fare',hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>
