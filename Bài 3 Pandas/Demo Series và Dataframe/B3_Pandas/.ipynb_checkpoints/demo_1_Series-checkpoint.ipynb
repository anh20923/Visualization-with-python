# %% [markdown]
# ## Import thư viện

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Tạo Series

# %%
# tạo series chứa tuổi của 5 nhân viên
age_lst = [25,27,24,28,30]
age_ser = pd.Series(age_lst)
age_ser
# Out:
# 0    25
# 1    27
# 2    24
# 3    28
# 4    30
# dtype: int64

# %%
# Tạo series từ list với index tường minh
age_ser = pd.Series([25,27,24,28,25,27,np.nan], 
                    index = ['em1', 'em2', 'em3', 'em4', 'em5', 'em6', 'em7'])
age_ser
# Out:
# em1    25.0
# em2    27.0
# em3    24.0
# em4    28.0
# em5    25.0
# em6    27.0
# em7     NaN
# dtype: float64

# %%
age_ser.mode()
# Out:
# 0    25.0
# 1    27.0
# dtype: float64

# %%
age_ser.value_counts()
# Out:
# 25.0    2
# 27.0    2
# 24.0    1
# 28.0    1
# Name: count, dtype: int64

# %% [markdown]
# ## Thuộc tính

# %%
age_ser.size # cho biết số phần tử trong series
# Out:
# 7

# %%
age_ser.shape # cho biết số chiều và số phần tử của series
# Out:
# (7,)

# %%
age_ser.index # cho biết các index của series
# Out:
# Index(['em1', 'em2', 'em3', 'em4', 'em5', 'em6', 'em7'], dtype='object')

# %%
age_ser.values # cho biết các values của series
# Out:
# array([25., 27., 24., 28., 25., 27., nan])

# %%
age_ser.dtype # cho biết kiểu dữ liệu của các phần tử trong series
# Out:
# dtype('float64')

# %% [markdown]
# ## Phương thức

# %%
age_ser.info() # thông tin info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7 entries, em1 to em7
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 6 non-null      float64
# dtypes: float64(1)
# memory usage: 412.0+ bytes

# %%
age_ser.head() # 5 phần tử đầu
# Out:
# em1    25.0
# em2    27.0
# em3    24.0
# em4    28.0
# em5    25.0
# dtype: float64

# %%
age_ser.tail() # 5 phần tử cuối
# Out:
# em3    24.0
# em4    28.0
# em5    25.0
# em6    27.0
# em7     NaN
# dtype: float64

# %%
age_ser.head(3) # 3 phần tử đầu
# Out:
# em1    25.0
# em2    27.0
# em3    24.0
# dtype: float64

# %%
age_ser.tail(2)
# Out:
# em6    27.0
# em7     NaN
# dtype: float64

# %%
age_ser.describe() # Thông tin thống kê chung
# Out:
# count     6.000000
# mean     26.000000
# std       1.549193
# min      24.000000
# 25%      25.000000
# 50%      26.000000
# 75%      27.000000
# max      28.000000
# dtype: float64

# %%
age_ser.std()
# Out:
# np.float64(1.5491933384829668)

# %%
age_ser.mean()
# Out:
# np.float64(26.0)

# %% [markdown]
# ## Truy xuất
# #### Truy xuất 1 phần tử

# %%
# label => index tường minh
# index => 2 index ngầm định
# tenseries.loc[label]
# tenseries.iloc[index]

# %%
age_ser = pd.Series([25,27,24,28,30,27,24], 
                    index = ['em3', 'em2', 'em1', 'em4', 'em7', 'em6', 'em5'])
age_ser
# Out:
# em3    25
# em2    27
# em1    24
# em4    28
# em7    30
# em6    27
# em5    24
# dtype: int64

# %%
# tuổi của nhân viên em3
age_ser.loc['em3']
# Out:
# np.int64(25)

# %%
age_ser.iloc[2]
# Out:
# np.int64(24)

# %%
age_ser.iloc[-5]
# Out:
# np.int64(24)

# %%
# tuổi của nhân viên cuối cùng
age_ser.iloc[-1]
# Out:
# np.int64(24)

# %%
# tuổi của nhân viên đầu tiên
age_ser.iloc[0]
# Out:
# np.int64(25)

# %%
# tuổi của nhân viên ở index 3
age_ser.iloc[3]
# Out:
# np.int64(28)

# %%
# Truy xuất 1 pt trực tiếp
# tenseries[label]
# tenseries[index] => label là chuỗi

# %%
age_ser
# Out:
# em3    25
# em2    27
# em1    24
# em4    28
# em7    30
# em6    27
# em5    24
# dtype: int64

# %%
# tuổi của nhân viên em1
age_ser['em1']
# Out:
# np.int64(24)

# %%
# tuổi của nhân viên em4
age_ser[-4]
# Out:
# C:\Users\Anh\AppData\Local\Temp\ipykernel_34720\2287266043.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   age_ser[-4]
# np.int64(28)

# %%
# lưu ý với ser có label là số (khác zero_based index)
lst = ['a','b','c','d']
s1 = pd.Series(lst,index=[1,2,3,4])
s1
# Out:
# 1    a
# 2    b
# 3    c
# 4    d
# dtype: object

# %%
s1[2]
# Out:
# 'b'

# %% [markdown]
# #### Truy xuất nhiều phần tử

# %%
# tenseries.loc[danh sách label]
# tenseries.loc[start : stop](bao gồm stop)
# tenseries.iloc[start : stop(-1) : step] => có quy tắc
# tenseries.iloc[danh sách index] => không quy tắc

# %%
age_ser
# Out:
# em3    25
# em2    27
# em1    24
# em4    28
# em7    30
# em6    27
# em5    24
# dtype: int64

# %%
age_ser.loc[['em1','em3']] # tuổi của nv em1, em3
# Out:
# em1    24
# em3    25
# dtype: int64

# %%
age_ser.loc['em1':'em7'] # tuổi của nv từ em1 đến em7
# Out:
# em1    24
# em4    28
# em7    30
# dtype: int64

# %%
age_ser.loc['em3':'em1']
# Out:
# em3    25
# em2    27
# em1    24
# dtype: int64

# %%
age_ser.loc['em1':'em6']
# Out:
# em1    24
# em4    28
# em7    30
# em6    27
# dtype: int64

# %%
age_ser.iloc[1:3] # tuổi của nv ở index 1,2
# Out:
# em2    27
# em1    24
# dtype: int64

# %%
age_ser.iloc[[0,1,4]] # tuổi của nv ở index 0,1,4
# Out:
# em3    25
# em2    27
# em7    30
# dtype: int64

# %%
# Truy xuất nhiều pt trực tiếp
# tenseries[danh sách label]
# tenseries[start:stop]
# tenseries[danh sách index] 
# tenseries[start:stop:step]

# %%
age_ser
# Out:
# em3    25
# em2    27
# em1    24
# em4    28
# em7    30
# em6    27
# em5    24
# dtype: int64

# %%
age_ser[1:3]
# Out:
# em2    27
# em1    24
# dtype: int64

# %%
age_ser[[0,2,3]]
# Out:
# C:\Users\Anh\AppData\Local\Temp\ipykernel_34720\409066710.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   age_ser[[0,2,3]]
# em3    25
# em1    24
# em4    28
# dtype: int64

# %%
age_ser[['em3','em4']]
# Out:
# em3    25
# em4    28
# dtype: int64

# %%
age_ser['em4':'em5']
# Out:
# em4    28
# em7    30
# em6    27
# em5    24
# dtype: int64

# %% [markdown]
# #### Truy xuất theo điều kiện

# %%
age_ser
# Out:
# em3    25
# em2    27
# em1    24
# em4    28
# em7    30
# em6    27
# em5    24
# dtype: int64

# %%
age_ser>25
# Out:
# em3    False
# em2     True
# em1    False
# em4     True
# em7     True
# em6     True
# em5    False
# dtype: bool

# %%
age_ser[age_ser>25]
# Out:
# em2    27
# em4    28
# em7    30
# em6    27
# dtype: int64

# %%
# Tuổi của các nhân viên > 25 và < 30 tuổi
age_ser[(age_ser>25) & (age_ser<30)] # and
# Out:
# em2    27
# em4    28
# em6    27
# dtype: int64

# %%
# Tuổi của các nhân viên dưới 25 hoặc trên 30 tuổi
age_ser[(age_ser<25) | (age_ser>=30)] # or
# Out:
# em1    24
# em7    30
# em5    24
# dtype: int64

# %%
age_ser[~(age_ser>25)]
# Out:
# em3    25
# em1    24
# em5    24
# dtype: int64

# %% [markdown]
# ## Xử lý dữ liệu trùng

# %%
# phone_ser lưu số điện thoại của nhân viên
phone_ser = pd.Series(['0912846759', '0914963258', '0978254361', '0335469512', '0914963258','0914963258', '0914963258'])
# phone_ser lưu số điện thoại của nhân viên
phone_ser
# Out:
# 0    0912846759
# 1    0914963258
# 2    0978254361
# 3    0335469512
# 4    0914963258
# 5    0914963258
# 6    0914963258
# dtype: object

# %%
# phát hiện trùng
phone_ser.duplicated() # mặc định keep=first
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# dtype: bool

# %%
phone_ser.duplicated(keep='last')
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# dtype: bool

# %%
phone_ser.duplicated(keep=False)
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# dtype: bool

# %%
phone_ser.drop_duplicates(inplace=True)

# %%
phone_ser
# Out:
# 0    0912846759
# 1    0914963258
# 2    0978254361
# 3    0335469512
# dtype: object

# %%
phone_ser.drop_duplicates(keep='last')
# Out:
# 0    0912846759
# 1    0914963258
# 2    0978254361
# 3    0335469512
# dtype: object

# %%
# xóa dữ liệu trùng
phone_ser.drop_duplicates(keep=False) # keep: first, last, False
# Out:
# 0    0912846759
# 1    0914963258
# 2    0978254361
# 3    0335469512
# dtype: object

# %%
phone_ser
# Out:
# 0    0912846759
# 1    0914963258
# 2    0978254361
# 3    0335469512
# dtype: object

# %%
phone_ser.drop_duplicates(keep=False,inplace=True)

# %%
phone_ser
# Out:
# 0    0912846759
# 1    0914963258
# 2    0978254361
# 3    0335469512
# dtype: object
