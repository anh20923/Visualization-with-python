# %% [markdown]
# *Italic*

# %% [markdown]
# **Bold**

# %% [markdown]
# # Heading 1

# %% [markdown]
# ## Heading 2

# %% [markdown]
# [Thông tin khóa học LTV Java](https://csc.edu.vn/lap-trinh-va-csdl/lap-trinh-vien-java_330)

# %% [markdown]
# ![DNS Query and Response Flow between Client and DNS Servers](DNS.png)

# %% [markdown]
# <img src = 'DNS.png' width ='100px' height ='200px'/>

# %% [markdown]
# > Comment

# %% [markdown]
# * bai1
# * bai2
# * bai3

# %% [markdown]
# Cai dat jupyter ` pip install jupyter `

# %% [markdown]
# ***

# %% [markdown]
# ```
# code blocks
# print a
# ```

# %% [markdown]
# ![thomas](thomas.jpeg)
